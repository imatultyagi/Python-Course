# %%
#Task 1:
import pandas as pd

marks = [45, 67, 89, 34, 90, 55, 72]
subjects = ['Math', 'Physics', 'Chemistry', 'English', 'CS', 'Biology', 'History']

s = pd.Series(marks, index=subjects)

# 1. Subjects with marks > 70
print("Subjects with marks > 70:")
print(s[s > 70])
print()

# 2. Replace marks < 40 with "Fail" (without type issues)
s2 = s.apply(lambda x: "Fail" if x < 40 else x)
print("After replacing marks < 40 with 'Fail':")
print(s2)
print()

# 3. Count subjects above average
avg = s.mean()
count_above_avg = (s > avg).sum()

print("Average marks:", avg)
print("Number of subjects above average:", count_above_avg)
# Out:
# Subjects with marks > 70:
# Chemistry    89
# CS           90
# History      72
# dtype: int64
#
# After replacing marks < 40 with 'Fail':
# Math           45
# Physics        67
# Chemistry      89
# English      Fail
# CS             90
# Biology        55
# History        72
# dtype: object
#
# Average marks: 64.57142857142857
# Number of subjects above average: 4
